# %%
import pandas as pd
import seaborn as sn

# %% [markdown]
# ### Extração de dados da planilha com Pandas e openpyxl

# %%
planilhas = ["Usuários","Incidentes","Ativos Monitorados","Antivírus","Plataformas"]
df_dados_criminais = pd.read_excel("Dados_Crimes_Ciberneticos_SP.xlsx", sheet_name=planilhas)

# %% [markdown]
# ### Visualização de planilhas

# %%
chaves = df_dados_criminais.keys()

for i in chaves:
    display(df_dados_criminais.get(i))
# Out:
#        ID             Bairro              Renda
# 0    1001    Jardim Paulista     Até 2 salários
# 1    1002    Jardim Paulista  De 2 a 6 salários
# 2    1003          Pinheiros  De 2 a 6 salários
# 3    1004       Vila Andrade  De 2 a 6 salários
# 4    1005         Itaim Bibi     Até 2 salários
# ..    ...                ...                ...
# 415  1416    Jardim Paulista  De 2 a 6 salários
# 416  1417          Pinheiros     Até 2 salários
# 417  1418  Cidade Tiradentes     Até 2 salários
# 418  1419         Guaianases     Até 2 salários
# 419  1420            Tatuapé  De 2 a 6 salários
#
# [420 rows x 3 columns]
#      ID Usuário Tipo de Ataque        Data   Hora           Status  \
# 0          1001         Adware  2025-03-29  09:07      Solucionado
# 1          1002         Adware  2025-03-16  01:43      Solucionado
# 2          1003         Adware  2025-03-25  20:45  Não solucionado
# 3          1004         Adware  2025-03-27  23:05      Solucionado
# ...

# %% [markdown]
# ### Tratamento de dados

# %% [markdown]
# ``` Verifica a quantidade de dados nulos ```

# %%
for i in planilhas:
    df_dados_criminais.get(i).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      420 non-null    int64
#  1   Bairro  420 non-null    object
#  2   Renda   420 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 10.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID Usuário           420 non-null    int64
#  1   Tipo de Ataque       420 non-null    object
#  2   Data                 420 non-null    object
#  3   Hora                 420 non-null    object
#  4   Status               420 non-null    object
#  5   Tempo para Resolver  420 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 19.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# ...

# %%
df_dados_criminais.get(planilhas[4]).isnull().sum()
# Out:
# ID Usuário          0
# Meio de Ataque      0
# Coluna1           420
# dtype: int64

# %% [markdown]
# ``` Remove coluna com valores nulos ```

# %%
plataformas = df_dados_criminais.get(planilhas[4]).dropna(axis=1)

# %% [markdown]
# ``` Verifica se há duplicatas ```

# %%
for i in planilhas:
    display(df_dados_criminais.get(i).duplicated().sum())
# Out:
# np.int64(0)
# np.int64(0)
# np.int64(0)
# np.int64(0)
# np.int64(0)

# %% [markdown]
# ``` Transformando em variáveis ```

# %%
usuarios = df_dados_criminais.get(planilhas[0])
incidentes = df_dados_criminais.get(planilhas[1])
ativos_monitorados = df_dados_criminais.get(planilhas[2])
antivirus = df_dados_criminais.get(planilhas[3])

# %% [markdown]
# ``` Setando ID ```

# %%
incidentes.rename(columns={'ID Usuário': 'ID'}, inplace=True)
ativos_monitorados.rename(columns={'ID Usuário': 'ID'}, inplace=True)
antivirus.rename(columns={'ID Usuário': 'ID'}, inplace=True)
plataformas.rename(columns={'ID Usuário': 'ID'}, inplace=True)
# Out:
# C:\Users\gefra\AppData\Local\Temp\ipykernel_22276\539917205.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plataformas.rename(columns={'ID Usuário': 'ID'}, inplace=True)

# %% [markdown]
# ``` Juntando Tabelas ```

# %%
# Fazer o merge dos dados
df = usuarios.merge(incidentes, on='ID')\
                           .merge(ativos_monitorados, on='ID')\
                           .merge(antivirus, on='ID')\
                           .merge(plataformas, on='ID')

# %%
df.head()
# Out:
#      ID           Bairro              Renda Tipo de Ataque        Data   Hora  \
# 0  1001  Jardim Paulista     Até 2 salários         Adware  2025-03-29  09:07
# 1  1002  Jardim Paulista  De 2 a 6 salários         Adware  2025-03-16  01:43
# 2  1003        Pinheiros  De 2 a 6 salários         Adware  2025-03-25  20:45
# 3  1004     Vila Andrade  De 2 a 6 salários         Adware  2025-03-27  23:05
# 4  1005       Itaim Bibi     Até 2 salários       Phishing  2025-03-24  21:25
#
#             Status Tempo para Resolver Dispositivo Sistema Operacional  \
# 0      Solucionado            1-2 dias     Celular         Windows 10+
# 1      Solucionado            1-2 dias  Computador         Windows 10+
# 2  Não solucionado            1-2 dias     Celular             iOS 14+
# 3      Solucionado      Mais de 3 dias     Celular         Android 10+
# 4      Solucionado      Mais de 3 dias     Celular         Android 10+
#
#           Antivírus      Meio de Ataque
# ...
